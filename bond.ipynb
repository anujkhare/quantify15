# %%
# import seaborn
import numpy as np
import pandas as pd
from patsy import dmatrices, dmatrix
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
# %pylab inline
import time
import sklearn
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lars
from sklearn import neighbors
from sklearn import gaussian_process
from sklearn.cross_validation import KFold
from sklearn.grid_search import GridSearchCV
import scipy.stats as stats
import scipy
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dfInitTrain = pd.read_csv('/root/code/gs/data/risk_Initial_Training_Data.csv', header=None)

# %%
dfInitTest = pd.read_csv('/root/code/gs/data/Initial_Test_Data.csv', header=None)

# %%
dfInitTrain.describe()
# Out:
#                0            1               2          3     4           5   \
# count        8501         8501            8312       8501  8493        8493
# unique       8500           23              27          3     2          12
# top     ISIN11140  sp rating16  moody rating10  Currency0     N  Seniority2
# freq            2         2087            1431       8499  8492        7333
#
#           6     7          8                 9                  10  \
# count   8501  8500       8498              8493               8481
# unique     3     8       2555                27                  6
# top        N     3  28-Feb-13  Collateral Type4  Coupon Frequency0
# freq    5203  8479         24              5133               7193
#
#                   11         12               13                14  \
# count           8501       8501             8501              8501
# unique            12       2474               77                13
# top     Coupon Type1  15-Mar-19  Industry Group0  Industry Sector0
# freq            7531         55             2250              3685
#
#                         15               16          17        18        19
# count                 8501             8501        8501      8495      8501
# unique                 308             1826        1342        32        17
# top     Industry SubGroup5  Issuer Name1354  Ticker1001  Country4  Stripe 1
# freq                  1478              629         631      7362      2179

# %%
dfInitTest.describe()
# Out:
#                0           1               2          3     4           5   \
# count        4944        4944            4595       4944  4943        4943
# unique       4944          24              26          2     2          11
# top     ISIN18359  sp rating1  moody rating15  Currency0     N  Seniority2
# freq            1         752             498       4943  4942        3957
#
#           6     7          8                 9                  10  \
# count   4944  4944       4941              4943               4940
# unique     3     7       1941                24                  5
# top        N     3  23-Jul-15  Collateral Type4  Coupon Frequency0
# freq    2473  4815         20              2323               4636
#
#                   11         12               13                14  \
# count           4944       4944             4944              4944
# unique            12       1552               74                12
# top     Coupon Type1  15-Jun-21  Industry Group0  Industry Sector0
# freq            4576         32              552              1429
#
#                          15               16          17        18
# count                  4944             4944        4944      4944
# unique                  280             1476        1167        33
# top     Industry SubGroup29  Issuer Name2014  Ticker1488  Country4
# freq                    373              218         218      3809

# %%
dfpre = pd.read_csv('/root/code/gs/data/preproces.csv', header=None)

# %%
dfpre.describe()
# Out:
#                  0            1            2     3     4            5   \
# count   8287.000000  8287.000000  8287.000000  8287  8287  8287.000000
# mean    6535.689272     8.878243     8.526849     0     0     2.170146
# std     3759.165591     5.926456     4.739507     0     0     0.990304
# min        0.000000     0.000000     0.000000     0     0     0.000000
# 25%     3403.500000     4.000000     5.000000     0     0     2.000000
# 50%     6782.000000     9.000000     7.000000     0     0     2.000000
# 75%     9660.500000    16.000000    11.000000     0     0     2.000000
# max    13507.000000    21.000000    27.000000     0     0    10.000000
#
#                 6            7              8            9            10  \
# count  8287.000000  8287.000000    8287.000000  8287.000000  8287.000000
# mean      0.387354     3.001207  733653.598769     3.991432     0.340775
# std       0.487175     0.124283    1761.627330     3.347743     0.893540
# min       0.000000     2.000000  725793.000000     0.000000     0.000000
# 25%       0.000000     3.000000  733366.000000     2.000000     0.000000
# 50%       0.000000     3.000000  734227.000000     4.000000     0.000000
# 75%       1.000000     3.000000  734781.500000     4.000000     0.000000
# max       1.000000    10.000000  735377.000000    33.000000     5.000000
#
#                 11             12           13           14           15  \
# count  8287.000000    8287.000000  8287.000000  8287.000000  8287.000000
# mean      1.183420  738769.512007    16.207433     2.390370    68.259805
# std       1.138767    2974.246036    17.538222     2.837377    71.515490
# min       0.000000  727276.000000     0.000000     0.000000     0.000000
# 25%       1.000000  736736.000000     0.000000     0.000000     5.000000
# 50%       1.000000  737817.000000    10.000000     1.000000    40.000000
# 75%       1.000000  739809.000000    28.000000     4.000000   109.000000
# max      12.000000  756547.000000    77.000000    11.000000   312.000000
#
#                 16           17           18           19
# count  8287.000000  8287.000000  8287.000000  8287.000000
# mean   1030.241342   694.146857     4.608181     3.296006
# std     564.452507   427.863499     2.853761     3.349987
# min       0.000000     0.000000     0.000000     0.000000
# 25%     568.000000   311.000000     4.000000     1.000000
# 50%    1054.000000   709.000000     4.000000     2.000000
# 75%    1414.000000  1001.000000     4.000000     5.000000
# max    2035.000000  1501.000000    35.000000    15.000000

# %%
dftest = pd.read_csv('/root/code/gs/data/pre_testdata.csv', header=None)

# %%
dftest.drop([3, 4], axis=1, inplace=True)

# %%
dfpre.drop([3, 4], axis=1, inplace=True)

# %%
trainData = np.array(dfpre, dtype='float')
testData = np.array(dftest, dtype='float')

# %%
df_final_train = pd.read_csv('/root/Downloads/pre_final_train.csv', header=None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-12-710008a8a475> in <module>()
# ----> 1 df_final_train = pd.read_csv('/root/Downloads/pre_final_train.csv', header=None)
#
# /home/kcm/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# /home/kcm/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     232
#     233     # Create the parser.
# --> 234     parser = TextFileReader(filepath_or_buffer, **kwds)
#     235
#     236     if (nrows is not None) and (chunksize is not None):
#
# /home/kcm/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     540             self.options['has_index_names'] = kwds['has_index_names']
#     541
# --> 542         self._make_engine(self.engine)
#     543
#     544     def _get_options_with_defaults(self, engine):
#
# /home/kcm/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     677     def _make_engine(self, engine='c'):
#     678         if engine == 'c':
# --> 679             self._engine = CParserWrapper(self.f, **self.options)
#     680         else:
#     681             if engine == 'python':
#
# /home/kcm/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1039         kwds['allow_leading_cols'] = self.index_col is not False
#    1040
# -> 1041         self._reader = _parser.TextReader(src, **kwds)
#    1042
#    1043         # XXX
#
# /home/kcm/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3218)()
#
# /home/kcm/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5594)()
#
# IOError: File /root/Downloads/pre_final_train.csv does not exist

# %%
df_final_train.notnull().all(axis=1).sum()

# %%
df_final_train

# %%
df_final_test = pd.read_csv('/root/Downloads/pre_final_test.csv', header=None)

# %%
df_final_test

# %% [markdown]
# ## TEST DATA

# %%
final_train = np.array(df_final_train.drop([3, 4], axis=1, inplace=False))
final_test = np.array(df_final_test.drop([3, 4], axis=1, inplace=False))
print final_train.shape, final_test.shape

# %%
ftrain_x = final_train[:, :-1]
ftrain_y = final_train[:, -1]

# %%
ftrain_x.shape

# %%
import time
import sklearn
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lars
from sklearn import neighbors
from sklearn import gaussian_process
from sklearn.cross_validation import KFold
from sklearn.grid_search import GridSearchCV

# %%
from sklearn import ensemble

# %%
clf = ensemble.RandomForestClassifier(n_estimators=500, oob_score=True, bootstrap=True)
clf.fit(ftrain_x, ftrain_y)
print clf.oob_score_

# %%
a = clf.predict(final_test)

# %%
clf_train = ensemble.RandomForestClassifier(n_estimators=500, oob_score=True)
clf_train.fit(train_x, train_y)
clf_train.oob_score_

# %%
clf_combined = ensemble.RandomForestClassifier(n_estimators=1100, oob_score=True)
clf_combined.fit(combined_x, combined_y)
clf_combined.oob_score_

# %%
final_test

# %%
a = clf_combined.predict(final_test)
output = zip(final_test[:, 0], a)

# %%
combined_x = np.zeros((train_x.shape[0] + ftrain_x.shape[0], 17))
combined_y = np.zeros((train_y.shape[0]+ftrain_y.shape[0],))

# %%
combined_x[:8287, :] = train_x
combined_x[8287:, :] = ftrain_x
combined_y[:8287 ] = train_y
combined_y[8287:] = ftrain_y

# %%
import csv
with open('test.csv', 'w') as fp:
    a = csv.writer(fp, delimiter=',')
    a.writerows(output)

# %% [markdown]
# ## TRAINING DATA!

# %%
NT = 7000

# %%
ind = [i for i in xrange(trainData.shape[0])]
numpy.random.shuffle(ind)
ind_train = ind[:NT]
ind_valid = ind[NT+1:]
print len(ind), len(ind_train), len(ind_valid)

# %%
train_x = trainData[:, :-1]
train_y = trainData[:, -1]
# valid_x = trainData[ind_valid, :-1]
# valid_y = trainData[ind_valid, -1]
test_x = testData

# %%
print trainData.shape, train_x.shape, train_y.shape
print valid_x.shape, valid_y.shape
print test_x.shape

# %%
F = train_x.shape[1]
ind_val = [1, 2]
ind_cat = [x for x in xrange(F) if x not in ind_val]
print F, ind_val, ind_cat

# %%
train_x.shape

# %%
combined

# %%
n_neighbors = 15
# we create an instance of Neighbours Classifier and fit the data.

# clf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance', metric='pyfunc', func=knnDist)
clf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
clf.fit(train_x, train_y)

print clf.score(valid_x, valid_y)

# %%
sklearn_pca = PCA(n_components=17)
pca_train = sklearn_pca.fit_transform(train_x)
R = np.dot(train_x.T, train_x)
w, a = scipy.linalg.eig(R)
w = abs(w)
eigval = sort(w)[::-1]
eigtot = sum(eigval)
print eigval[0] / eigtot

# %%
sklearn_pca = PCA(n_components=17)
pca_valid = sklearn_pca.fit_transform(valid_x)
R = np.dot(valid_x.T, valid_x)
w, a = scipy.linalg.eig(R)
w = abs(w)
eigval = sort(w)[::-1]
eigtot = sum(eigval)
print eigval[0] / eigtot

# %%
pca_valid.shape

# %%
n_neighbors = 15

# clf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance', metric='pyfunc', func=knnDist)
clf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
clf.fit(pca_train, train_y)

print clf.score(pca_valid, valid_y)

# %%
ensemble.RandomForestClassifier()
